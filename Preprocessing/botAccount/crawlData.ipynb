# %%
import asyncio
from twscrape import API, gather
from twscrape.logger import set_log_level
import json
import csv
from datetime import datetime

class DateTimeEncoder(json.JSONEncoder):
    def default(self, o):
        if isinstance(o, datetime):
            return o.isoformat()
        elif hasattr(o, '__dict__'):
            return o.__dict__
        return super().default(o)

async def get_user_additional_info(api, user_id):
    try:
        user = await api.user_by_id(user_id)

        if user is not None:
            user_details = {
                'id': user.id,
                'username': user.username,
                'displayName': user.displayname,
                'url': user.url,
                'intro': user.rawDescription,
                'join_date': user.created,
                'location': user.location,
                'friends_count': user.friendsCount,
                'favorite_count':user.favouritesCount,
                'followers_count': user.followersCount,
                'media_count': user.mediaCount,
                'status_count': user.statusesCount,
                'listed_count': user.listedCount,
                'is_protected': user.protected,
                'is_verified': user.verified,
            }

            filename = "profileBotorNot.json"
            with open(filename, 'a', encoding='utf-8') as file:
                json.dump(user_details, file, ensure_ascii=False, indent=4, cls=DateTimeEncoder)

            print(f"Data for {user_id} has been successfully exported to file ")
        else:
            print(f"User {user_id} not found or has no ID.")
    except Exception as e:
        print(f"Error fetching user details: {e}")
        return None            

async def main():
    api = API()
    #await api.pool.add_account("your_username", "your_password", "your_email@example.com", "your_email_password")
    await api.pool.login_all()

    csv_file_path = r"twitter_human_bots_dataset.csv"

    # Read the CSV file
    with open(csv_file_path, "r") as file:
        # Create a CSV reader object
        reader = csv.reader(file)

        # Convert the reader object to a list
        rows = list(reader)

        # Iterate over each row in the CSV file
        for row in rows[1:]:
            # Access the values in each row
            # For example, to access the first column:
            value = row[0]
            await get_user_additional_info(api,value)
            
    set_log_level("DEBUG")

    # Other actions you may want to perform using the API

if __name__ == "__main__":
    await main()
# Out:
# Data for 787405734442958848 has been successfully exported to file
# Data for 796216118331310080 has been successfully exported to file
# Data for 875949740503859204 has been successfully exported to file
# Data for 756119643622735875 has been successfully exported to file
# Data for 464781334 has been successfully exported to file
# User 800833795234611200 not found or has no ID.
# Data for 55050269 has been successfully exported to file
# User 809500704 not found or has no ID.
# Data for 1015021614 has been successfully exported to file
# Data for 492306486 has been successfully exported to file
# Data for 432537664 has been successfully exported to file
# Data for 2579497028 has been successfully exported to file
# Data for 19660870 has been successfully exported to file
# Data for 313087874 has been successfully exported to file
# Data for 211550281 has been successfully exported to file
# Data for 769392715 has been successfully exported to file
# Data for 772106131875500032 has been successfully exported to file
# Data for 772521707810787328 has been successfully exported to file
# Data for 476691783 has been successfully exported to file
# Data for 384565337 has been successfully exported to file
# Data for 305922144 has been successfully exported to file
# Data for 1183842404 has been successfully exported to file
# Data for 253755500 has been successfully exported to file
# Data for 368050288 has been successfully exported to file
# Data for 14418045 has been successfully exported to file
# Data for 296484990 has been successfully exported to file
# Data for 932049341862240256 has been successfully exported to file
# Data for 99352713 has been successfully exported to file
# Data for 519045260 has been successfully exported to file
# Data for 115343506 has been successfully exported to file
# User 2166882457 not found or has no ID.
# Data for 381157528 has been successfully exported to file
# Data for 721944734 has been successfully exported to file
# Data for 3392143521 has been successfully exported to file
# Data for 23330998 has been successfully exported to file
# Data for 63176889 has been successfully exported to file
# Data for 239861947 has been successfully exported to file
# Data for 21758143 has been successfully exported to file
# Data for 765944091385421824 has been successfully exported to file
# Data for 19923144 has been successfully exported to file
# Data for 235667666 has been successfully exported to file
# Data for 1191444692 has been successfully exported to file
# Data for 2499018968 has been successfully exported to file
# Data for 557842655 has been successfully exported to file
# Data for 23331044 has been successfully exported to file
# Data for 321388777 has been successfully exported to file
# Data for 298320111 has been successfully exported to file
# Data for 51904755 has been successfully exported to file
# Data for 243794165 has been successfully exported to file
# Data for 2918711542 has been successfully exported to file
# User 123470069 not found or has no ID.
# Data for 2943615224 has been successfully exported to file
# Data for 127664378 has been successfully exported to file
# Data for 1084227842 has been successfully exported to file
# Data for 122159370 has been successfully exported to file
# Data for 39321874 has been successfully exported to file
# Data for 949036672741793793 has been successfully exported to file
# Data for 2178679070 has been successfully exported to file
# Data for 2980315426 has been successfully exported to file
# Data for 17039652 has been successfully exported to file
# Data for 1014793793353199617 has been successfully exported to file
# Data for 202375506 has been successfully exported to file
# Data for 347865421 has been successfully exported to file
# Data for 572785000 has been successfully exported to file
# Data for 4790681969 has been successfully exported to file
# Data for 380457314 has been successfully exported to file
# Data for 15729017 has been successfully exported to file
# Data for 596377986 has been successfully exported to file
# Data for 711721350 has been successfully exported to file
# Data for 326369679 has been successfully exported to file
# Data for 866648466 has been successfully exported to file
# Data for 708759570319953920 has been successfully exported to file
# Data for 722003254716944384 has been successfully exported to file
# Data for 418 has been successfully exported to file
# User 19399072 not found or has no ID.
# Data for 875782003244892160 has been successfully exported to file
# Data for 734035576068788225 has been successfully exported to file
# Data for 816463277643288577 has been successfully exported to file
# Data for 611582397 has been successfully exported to file
# Data for 57409991 has been successfully exported to file
# Data for 46662096 has been successfully exported to file
# Data for 101974483 has been successfully exported to file
# Data for 2610430435 has been successfully exported to file
# Data for 38797799 has been successfully exported to file
# Data for 30409200 has been successfully exported to file
# Data for 24117754 has been successfully exported to file
# Data for 491258363 has been successfully exported to file
# Data for 4112253434 has been successfully exported to file
# Data for 872826012794585089 has been successfully exported to file
# Data for 876795381841100801 has been successfully exported to file
# Data for 287834630 has been successfully exported to file
# User 62915097 not found or has no ID.
# Data for 261620277 has been successfully exported to file
# Data for 15729207 has been successfully exported to file
# Data for 114557496 has been successfully exported to file
# Data for 19923515 has been successfully exported to file
# Data for 50856512 has been successfully exported to file
# Data for 1377305161 has been successfully exported to file
# Data for 586 has been successfully exported to file
# Data for 30147163 has been successfully exported to file
# Data for 483656289 has been successfully exported to file
# Data for 848036460 has been successfully exported to file
# Data for 336069232 has been successfully exported to file
# Data for 128799124 has been successfully exported to file
# Data for 114557557 has been successfully exported to file
# Data for 111673973 has been successfully exported to file
# Data for 848822905 has been successfully exported to file
# Data for 265814650 has been successfully exported to file
# Data for 133694084 has been successfully exported to file
# Data for 1658061462 has been successfully exported to file
# Data for 60031646 has been successfully exported to file
# Data for 111936162 has been successfully exported to file
# Data for 2768241314 has been successfully exported to file
# Data for 703857318 has been successfully exported to file
# User 632029895 not found or has no ID.
# Data for 1587544788 has been successfully exported to file
# Data for 243794651 has been successfully exported to file
# Data for 788792041 has been successfully exported to file
# Data for 1692140268 has been successfully exported to file
# Data for 15467245 has been successfully exported to file
# Data for 721683182 has been successfully exported to file
# Data for 3282830066 has been successfully exported to file
# Data for 20447988 has been successfully exported to file
# Data for 94896901 has been successfully exported to file
# Data for 88081160 has been successfully exported to file
# Data for 63701775 has been successfully exported to file
# Data for 30933781 has been successfully exported to file
# Data for 889213107112996864 has been successfully exported to file
# User 276562720 not found or has no ID.
# Data for 256115497 has been successfully exported to file
# User 4848354100 not found or has no ID.
# User 2318140218 not found or has no ID.
# Data for 2581857086 has been successfully exported to file
# Data for 1739064128 has been successfully exported to file
# User 47186755 not found or has no ID.
# Data for 861135093213138944 has been successfully exported to file
# Data for 20710218 has been successfully exported to file
# Data for 20972371 has been successfully exported to file
# Data for 1681392474 has been successfully exported to file
# Data for 795083617 has been successfully exported to file
# Data for 221512549 has been successfully exported to file
# Data for 18088810 has been successfully exported to file
# User 29361001 not found or has no ID.
# Data for 939262832 has been successfully exported to file
# Data for 3101950833 has been successfully exported to file
# Data for 386139005 has been successfully exported to file
# Data for 220464007 has been successfully exported to file
# Data for 792462217 has been successfully exported to file
# Data for 477365128 has been successfully exported to file
# Data for 39846828 has been successfully exported to file
# Data for 1849164720 has been successfully exported to file
# Data for 91227068 has been successfully exported to file
# Data for 34866114 has been successfully exported to file
# Data for 1021313990 has been successfully exported to file
# Data for 41681878 has been successfully exported to file
# Data for 34079698 has been successfully exported to file
# User 409207765 not found or has no ID.
# Data for 24642526 has been successfully exported to file
# Data for 1034115201979826178 has been successfully exported to file
# Data for 24380395 has been successfully exported to file
# Data for 46662639 has been successfully exported to file
# Data for 172753966 has been successfully exported to file
# Data for 18351153 has been successfully exported to file
# Data for 863765552 has been successfully exported to file
# Data for 856949808 has been successfully exported to file
# User 495453239 not found or has no ID.
# Data for 800588862 has been successfully exported to file
# Data for 120587348 has been successfully exported to file
# User 307233876 not found or has no ID.
# Data for 342099030 has been successfully exported to file
# Data for 5768282 has been successfully exported to file
# Data for 448529505 has been successfully exported to file
# Data for 1006905571994472448 has been successfully exported to file
# Data for 202900592 has been successfully exported to file
# Data for 38536306 has been successfully exported to file
# Data for 130286723 has been successfully exported to file
# Data for 897589708162830337 has been successfully exported to file
# Data for 2362967176 has been successfully exported to file
# Data for 171705488 has been successfully exported to file
# Data for 78120081 has been successfully exported to file
# Data for 769650999942340608 has been successfully exported to file
# Data for 78644388 has been successfully exported to file
# Data for 765838109976190976 has been successfully exported to file
# Data for 1320158370 has been successfully exported to file
# User 833356976 not found or has no ID.
# Data for 29885619 has been successfully exported to file
# Data for 877343511858692096 has been successfully exported to file
# Data for 1028654280 has been successfully exported to file
# Data for 970982604 has been successfully exported to file
# Data for 42730704 has been successfully exported to file
# Data for 2961704150 has been successfully exported to file
# Data for 85722328 has been successfully exported to file
# Data for 497288416 has been successfully exported to file
# Data for 403703016 has been successfully exported to file
# Data for 320603385 has been successfully exported to file
# Data for 880018682 has been successfully exported to file
# Data for 29099266 has been successfully exported to file
# Data for 400557314 has been successfully exported to file
# Data for 4328785158 has been successfully exported to file
# Data for 877379085214679040 has been successfully exported to file
# Data for 2622731 has been successfully exported to file
# User 331613467 not found or has no ID.
# Data for 957089052 has been successfully exported to file
# Data for 2984510759 has been successfully exported to file
# Data for 439878961 has been successfully exported to file
# Data for 27526457 has been successfully exported to file
# Data for 896533819 has been successfully exported to file
# Data for 350487871 has been successfully exported to file
# Data for 123209023 has been successfully exported to file
# Data for 45090120 has been successfully exported to file
# User 2444756300 not found or has no ID.
# Data for 14157134 has been successfully exported to file
# Data for 14681449 has been successfully exported to file
# Data for 969324483185119232 has been successfully exported to file
# Data for 982628478284595200 has been successfully exported to file
# Data for 839237419815796736 has been successfully exported to file
# Data for 321389968 has been successfully exported to file
# Data for 22021524 has been successfully exported to file
# Data for 304088468 has been successfully exported to file
# Data for 480249240 has been successfully exported to file
# Data for 765659108854857729 has been successfully exported to file
# Data for 50595242 has been successfully exported to file
# Data for 16254381 has been successfully exported to file
# Data for 837027265 has been successfully exported to file
# Data for 1126958532 has been successfully exported to file
# Data for 38536646 has been successfully exported to file
# Data for 215745990 has been successfully exported to file
# Data for 2334131662 has been successfully exported to file
# Data for 74712538 has been successfully exported to file
# Data for 2727609826 has been successfully exported to file
# Data for 179832300 has been successfully exported to file
# Data for 2425882104 has been successfully exported to file
# Data for 3077047801 has been successfully exported to file
# User 1125910016 not found or has no ID.
# Data for 171968009 has been successfully exported to file
# Data for 301729291 has been successfully exported to file
# Data for 74450446 has been successfully exported to file
# Data for 1604847120 has been successfully exported to file
# Data for 362284562 has been successfully exported to file
# User 1719404058 not found or has no ID.
# User 2444756510 not found or has no ID.
# Data for 568854046 has been successfully exported to file
# Data for 867436081 has been successfully exported to file
# User 3164603961 not found or has no ID.
# Data for 772504122608214016 has been successfully exported to file
# Data for 318768709 has been successfully exported to file
# Data for 835368880277159936 has been successfully exported to file
# Data for 1733822028 has been successfully exported to file
# Data for 328205906 has been successfully exported to file
# Data for 890678446698975233 has been successfully exported to file
# Data for 217319002 has been successfully exported to file
# Data for 4903929447 has been successfully exported to file
# Data for 894666092710383618 has been successfully exported to file
# Data for 1661470322 has been successfully exported to file
# Data for 28313220 has been successfully exported to file
# Data for 214697607 has been successfully exported to file
# Data for 242484876 has been successfully exported to file
# Data for 3483877814 has been successfully exported to file
# Data for 18089641 has been successfully exported to file
# Data for 316147373 has been successfully exported to file
# Data for 969672378 has been successfully exported to file
# User 293340865 not found or has no ID.
# Data for 476317382 has been successfully exported to file
# User 48236235 not found or has no ID.
# User 349177562 not found or has no ID.
# Data for 1069811420 has been successfully exported to file
# Data for 35391199 has been successfully exported to file
# Data for 8652512 has been successfully exported to file
# Data for 305399525 has been successfully exported to file
# Data for 217319143 has been successfully exported to file
# Data for 878028362589118464 has been successfully exported to file
# User 2444232436 not found or has no ID.
# Data for 453510918 has been successfully exported to file
# User 150996744 not found or has no ID.
# Data for 2465466121 has been successfully exported to file
# User 885524240 not found or has no ID.
# Data for 888145681 has been successfully exported to file
# Data for 272893712 has been successfully exported to file
# Data for 452462357 has been successfully exported to file
# User 9963292 not found or has no ID.
# Data for 1680869150 has been successfully exported to file
# Data for 15730467 has been successfully exported to file
# Data for 772384385609920512 has been successfully exported to file
# Data for 772179253676896256 has been successfully exported to file
# Data for 268961586 has been successfully exported to file
# Data for 387450674 has been successfully exported to file
# Data for 877353395538935808 has been successfully exported to file
# Data for 238028607 has been successfully exported to file
# Data for 241698625 has been successfully exported to file
# Data for 940050242 has been successfully exported to file
# Data for 917505878 has been successfully exported to file
# Data for 803412430193770496 has been successfully exported to file
# Data for 807229152612925440 has been successfully exported to file
# User 242747238 not found or has no ID.
# Data for 34867057 has been successfully exported to file
# Data for 495716215 has been successfully exported to file
# Data for 36439939 has been successfully exported to file
# Data for 52430724 has been successfully exported to file
# Data for 73140135 has been successfully exported to file
# Data for 125568955 has been successfully exported to file
# Data for 219416510 has been successfully exported to file
# Data for 225445834 has been successfully exported to file
# Data for 2932344784 has been successfully exported to file
# Data for 50595800 has been successfully exported to file
# Data for 856426471 has been successfully exported to file
# Data for 19924969 has been successfully exported to file
# Data for 2301364213 has been successfully exported to file
# Data for 599001082 has been successfully exported to file
# Data for 147589125 has been successfully exported to file
# Data for 796252778066743296 has been successfully exported to file
# Data for 778553286022533120 has been successfully exported to file
# User 2196506641 not found or has no ID.
# Data for 883951634 has been successfully exported to file
# Data for 2563770386 has been successfully exported to file
# Data for 161482772 has been successfully exported to file
# Data for 1602488347 has been successfully exported to file
# Data for 178260000 has been successfully exported to file
# Data for 614467617 has been successfully exported to file
# Data for 372508707 has been successfully exported to file
# Data for 3236431915 has been successfully exported to file
# Data for 113248312 has been successfully exported to file
# Data for 762841146 has been successfully exported to file
# Data for 315623483 has been successfully exported to file
# Data for 2728659003 has been successfully exported to file
# Data for 20711495 has been successfully exported to file
# Data for 80480330 has been successfully exported to file
# Data for 1885079629 has been successfully exported to file
# Data for 99092563 has been successfully exported to file
# Data for 6031442 has been successfully exported to file
# Data for 1711016023 has been successfully exported to file
# Data for 1976043619 has been successfully exported to file
# Data for 412354660 has been successfully exported to file
# Data for 38537315 has been successfully exported to file
# Data for 216533096 has been successfully exported to file
# Data for 849266279848562689 has been successfully exported to file
# Data for 103024765 has been successfully exported to file
# Data for 2530740348 has been successfully exported to file
# Data for 736750345095942144 has been successfully exported to file
# User 786988812312449024 not found or has no ID.
# Data for 837344043021570049 has been successfully exported to file
# User 710892812192124929 not found or has no ID.
# Data for 784471315898109953 has been successfully exported to file
# Data for 806067753505460225 has been successfully exported to file
# Data for 822532286138748930 has been successfully exported to file
# Data for 107481236 has been successfully exported to file
# Data for 732736395891118083 has been successfully exported to file
# Data for 106170524 has been successfully exported to file
# 2023-12-08 11:50:52.689 | WARNING  | twscrape.queue_client:req:208 - Unknown error <class 'twscrape.queue_client.ApiError'>: ApiError on 252/500 - Acc1B1133 (code 200): OverCapacity: Unspecified
# 2023-12-08 11:50:53.941 | WARNING  | twscrape.queue_client:req:208 - Unknown error <class 'twscrape.queue_client.ApiError'>: ApiError on 499/500 - Acc2Bigdat967 (code 200): OverCapacity: Unspecified
# 2023-12-08 11:50:55.146 | WARNING  | twscrape.queue_client:req:208 - Unknown error <class 'twscrape.queue_client.ApiError'>: ApiError on 499/500 - BigDataAcc01 (code 200): OverCapacity: Unspecified
# Data for 771923395961360389 has been successfully exported to file
# Data for 90704023 has been successfully exported to file
# Data for 28838048 has been successfully exported to file
# Data for 38799543 has been successfully exported to file
# Data for 67635391 has been successfully exported to file
# Data for 14944471 has been successfully exported to file
# User 288884968 not found or has no ID.
# User 35916009 not found or has no ID.
# Data for 278399214 has been successfully exported to file
# User 321390831 not found or has no ID.
# Data for 205261048 has been successfully exported to file
# Data for 843798888481927168 has been successfully exported to file
# Data for 2431387897 has been successfully exported to file
# User 251136261 not found or has no ID.
# Data for 188483855 has been successfully exported to file
# Data for 2253916442 has been successfully exported to file
# Data for 1249904934 has been successfully exported to file
# Data for 17828140 has been successfully exported to file
# Data for 119802157 has been successfully exported to file
# Data for 41421105 has been successfully exported to file
# Data for 236980532 has been successfully exported to file
# Data for 713039970680881153 has been successfully exported to file
# Data for 4820306248 has been successfully exported to file
# Data for 39586129 has been successfully exported to file
# Data for 2590771538 has been successfully exported to file
# Data for 248252756 has been successfully exported to file
# Data for 879710844325703680 has been successfully exported to file
# Data for 896153708991590400 has been successfully exported to file
# Data for 146540920 has been successfully exported to file
# Data for 420219280 has been successfully exported to file
# Data for 231999899 has been successfully exported to file
# Data for 298060189 has been successfully exported to file
# Data for 781888610320678912 has been successfully exported to file
# Data for 772262928795992064 has been successfully exported to file
# Data for 403179950 has been successfully exported to file
# Data for 24906161 has been successfully exported to file
# Data for 877326428399779840 has been successfully exported to file
# Data for 262146488 has been successfully exported to file
# Data for 369625532 has been successfully exported to file
# User 842870779066945536 not found or has no ID.
# Data for 20449731 has been successfully exported to file
# Data for 3266054594 has been successfully exported to file
# Data for 37751238 has been successfully exported to file
# Data for 877293082177306624 has been successfully exported to file
# Data for 18614747 has been successfully exported to file
# Data for 2307656165 has been successfully exported to file
# Data for 5507572 has been successfully exported to file
# Data for 12585462 has been successfully exported to file
# Data for 177474041 has been successfully exported to file
# Data for 25954814 has been successfully exported to file
# Data for 787483152 has been successfully exported to file
# Data for 405015059 has been successfully exported to file
# Data for 4848093719 has been successfully exported to file
# Data for 547097112 has been successfully exported to file
# User 467991054 not found or has no ID.
# Data for 111938071 has been successfully exported to file
# Data for 20711964 has been successfully exported to file
# Data for 22284834 has been successfully exported to file
# Data for 3312192048 has been successfully exported to file
# Data for 279185985 has been successfully exported to file
# Data for 906758731 has been successfully exported to file
# Data for 2532837963 has been successfully exported to file
# Data for 878447185 has been successfully exported to file
# Data for 592972389 has been successfully exported to file
# Data for 60820070 has been successfully exported to file
# Data for 42207855 has been successfully exported to file
# Data for 72878707 has been successfully exported to file
# Data for 46926453 has been successfully exported to file
# Data for 19925621 has been successfully exported to file
# Data for 351799946 has been successfully exported to file
# Data for 3299871373 has been successfully exported to file
# Data for 790701621181292544 has been successfully exported to file
# Data for 803570644843634688 has been successfully exported to file
# User 3077835414 not found or has no ID.
# Data for 124258971 has been successfully exported to file
# Data for 19663518 has been successfully exported to file
# User 37489316 not found or has no ID.
# Data for 803356645950627841 has been successfully exported to file
# Data for 15731377 has been successfully exported to file
# Data for 132385468 has been successfully exported to file
# Data for 772455418455007234 has been successfully exported to file
# Data for 227019467 has been successfully exported to file
# Data for 413403853 has been successfully exported to file
# Data for 44829395 has been successfully exported to file
# Data for 175639254 has been successfully exported to file
# Data for 460279825 has been successfully exported to file
# Data for 2337802973 has been successfully exported to file
# Data for 91491046 has been successfully exported to file
# Data for 1516505838 has been successfully exported to file
# Data for 165153530 has been successfully exported to file
# Data for 279710472 has been successfully exported to file
# User 247991049 not found or has no ID.
# Data for 226757393 has been successfully exported to file
# User 71568164 not found or has no ID.
# Data for 805571370 has been successfully exported to file
# User 630459182 not found or has no ID.
# Data for 348654395 has been successfully exported to file
# Data for 436996936 has been successfully exported to file
# Data for 61868891 has been successfully exported to file
# Data for 73141088 has been successfully exported to file
# Data for 1219758966 has been successfully exported to file
# Data for 3300133759 has been successfully exported to file
# User 715918219 not found or has no ID.
# Data for 4849142669 has been successfully exported to file
# Data for 23595924 has been successfully exported to file
# Data for 18353044 has been successfully exported to file
# Data for 393743257 has been successfully exported to file
# Data for 310643621 has been successfully exported to file
# Data for 754373350676271104 has been successfully exported to file
# Data for 265554862 has been successfully exported to file
# User 2363231167 not found or has no ID.
# Data for 4384885696 has been successfully exported to file
# Data for 772428274702090240 has been successfully exported to file
# Data for 1233652698 has been successfully exported to file
# Data for 103025630 has been successfully exported to file
# Data for 24906723 has been successfully exported to file
# Data for 46664677 has been successfully exported to file
# Data for 132385773 has been successfully exported to file
# Data for 875894126855802880 has been successfully exported to file
# Data for 34343928 has been successfully exported to file
# Data for 18091004 has been successfully exported to file
# Data for 379325443 has been successfully exported to file
# Data for 790629380 has been successfully exported to file
# Data for 38973772 has been successfully exported to file
# Data for 250350611 has been successfully exported to file
# Data for 2610433058 has been successfully exported to file
# Data for 64228387 has been successfully exported to file
# Data for 20974645 has been successfully exported to file
# Data for 483396662 has been successfully exported to file
# Data for 342363193 has been successfully exported to file
# Data for 2718436417 has been successfully exported to file
# Data for 2171079759 has been successfully exported to file
# Data for 1002441816 has been successfully exported to file
# Data for 114035804 has been successfully exported to file
# Data for 769633309722763264 has been successfully exported to file
# Data for 875835223480557568 has been successfully exported to file
# Data for 2794720358 has been successfully exported to file
# Data for 53218408 has been successfully exported to file
# Data for 19139694 has been successfully exported to file
# Data for 482610286 has been successfully exported to file
# Data for 2158759025 has been successfully exported to file
# Data for 3979873394 has been successfully exported to file
# Data for 14421107 has been successfully exported to file
# Data for 538446976 has been successfully exported to file
# Data for 2573208707 has been successfully exported to file
# Data for 71225650 has been successfully exported to file
# Data for 153619589 has been successfully exported to file
# Data for 711050934109876224 has been successfully exported to file
# Data for 27528339 has been successfully exported to file
# Data for 784286171673145344 has been successfully exported to file
# User 2468088978 not found or has no ID.
# Data for 556534934 has been successfully exported to file
# Data for 90967197 has been successfully exported to file
# Data for 772293092900614145 has been successfully exported to file
# Data for 231214259 has been successfully exported to file
# Data for 3178499254 has been successfully exported to file
# Data for 292555960 has been successfully exported to file
# User 1414794427 not found or has no ID.
# User 299371708 not found or has no ID.
# User 94899391 not found or has no ID.
# Data for 122162381 has been successfully exported to file
# Data for 28052685 has been successfully exported to file
# Data for 38538449 has been successfully exported to file
# Data for 2214071510 has been successfully exported to file
# Data for 637275359 has been successfully exported to file
# Data for 304352481 has been successfully exported to file
# Data for 357567715 has been successfully exported to file
# Data for 2458389740 has been successfully exported to file
# Data for 30412016 has been successfully exported to file
# Data for 2560101619 has been successfully exported to file
# Data for 1335364873 has been successfully exported to file
# Data for 109579534 has been successfully exported to file
# Data for 323226897 has been successfully exported to file
# Data for 2992377108 has been successfully exported to file
# Data for 59247894 has been successfully exported to file
# Data for 17304859 has been successfully exported to file
# Data for 24382752 has been successfully exported to file
# Data for 616303909 has been successfully exported to file
# User 1548750122 not found or has no ID.
# Data for 315886893 has been successfully exported to file
# Data for 210242862 has been successfully exported to file
# Data for 81530160 has been successfully exported to file
# Data for 149163313 has been successfully exported to file
# Data for 630197568 has been successfully exported to file
# Data for 772208410494459908 has been successfully exported to file
# Data for 25693507 has been successfully exported to file
# Data for 581438790 has been successfully exported to file
# Data for 703335756 has been successfully exported to file
# User 2459700563 not found or has no ID.
# Data for 365694298 has been successfully exported to file
# Data for 244845936 has been successfully exported to file
# Data for 3332902257 has been successfully exported to file
# Data for 1891896709 has been successfully exported to file
# Data for 2729708935 has been successfully exported to file
# Data for 848039305 has been successfully exported to file
# Data for 382995849 has been successfully exported to file
# Data for 298585488 has been successfully exported to file
# Data for 544738709 has been successfully exported to file
# Data for 498863526 has been successfully exported to file
# Data for 875803402613260289 has been successfully exported to file
# Data for 1181748655 has been successfully exported to file
# Data for 20450738 has been successfully exported to file
# Data for 7081402 has been successfully exported to file
# Data for 376966590 has been successfully exported to file
# Data for 3257929151 has been successfully exported to file
# Data for 796091152437018624 has been successfully exported to file
# Data for 159387080 has been successfully exported to file
# Data for 1252265444 has been successfully exported to file
# Data for 2565606889 has been successfully exported to file
# Data for 102239729 has been successfully exported to file
# Data for 2329415154 has been successfully exported to file
# Data for 1979190776 has been successfully exported to file
# Data for 890648800095752192 has been successfully exported to file
# User 544214527 not found or has no ID.
# Data for 2818051585 has been successfully exported to file
# Data for 823660038 has been successfully exported to file
# Data for 267390486 has been successfully exported to file
# Data for 177737258 has been successfully exported to file
# Data for 599264817 has been successfully exported to file
# Data for 4162850356 has been successfully exported to file
# Data for 3121352247 has been successfully exported to file
# Data for 266866249 has been successfully exported to file
# Data for 42208855 has been successfully exported to file
# Data for 67636824 has been successfully exported to file
# Data for 21761627 has been successfully exported to file
# Data for 479727198 has been successfully exported to file
# Data for 64753254 has been successfully exported to file
# Data for 209456754 has been successfully exported to file
# Data for 31523146 has been successfully exported to file
# Data for 189271687 has been successfully exported to file
# Data for 458755731 has been successfully exported to file
# Data for 958334130827284481 has been successfully exported to file
# Data for 58461854 has been successfully exported to file
# Data for 583012000 has been successfully exported to file
# Data for 956829350 has been successfully exported to file
# Data for 123997878 has been successfully exported to file
# Data for 24907451 has been successfully exported to file
# User 15732429 not found or has no ID.
# Data for 40898254 has been successfully exported to file
# Data for 34868950 has been successfully exported to file
# Data for 44306137 has been successfully exported to file
# Data for 24383198 has been successfully exported to file
# Data for 3506959932 has been successfully exported to file
# User 464260842 not found or has no ID.
# User 24645354 not found or has no ID.
# Data for 78384881 has been successfully exported to file
# Data for 949948733831110657 has been successfully exported to file
# Data for 1037140892337954822 has been successfully exported to file
# Data for 50859813 has been successfully exported to file
# Data for 890673349818548224 has been successfully exported to file
# Data for 272633657 has been successfully exported to file
# Data for 24907585 has been successfully exported to file
# User 23859014 not found or has no ID.
# Data for 42733384 has been successfully exported to file
# Data for 2919763790 has been successfully exported to file
# Data for 134745940 has been successfully exported to file
# Data for 61869915 has been successfully exported to file
# Data for 269225854 has been successfully exported to file
# Data for 18091904 has been successfully exported to file
# Data for 453513089 has been successfully exported to file
# Data for 164438347 has been successfully exported to file
# Data for 1289228173 has been successfully exported to file
# Data for 6819732 has been successfully exported to file
# Data for 415764375 has been successfully exported to file
# Data for 324538274 has been successfully exported to file
# Data for 88084392 has been successfully exported to file
# User 197660588 not found or has no ID.
# Data for 22548403 has been successfully exported to file
# Data for 19926982 has been successfully exported to file
# Data for 966837667282513925 has been successfully exported to file
# Data for 139202541 has been successfully exported to file
# Data for 87035888 has been successfully exported to file
# User 709923207847874560 not found or has no ID.
# Data for 758382951532859393 has been successfully exported to file
# Data for 928314603376742400 has been successfully exported to file
# Data for 790302681537449985 has been successfully exported to file
# Data for 780929716173672452 has been successfully exported to file
# Data for 94900238 has been successfully exported to file
# Data for 3017805851 has been successfully exported to file
# Data for 189009947 has been successfully exported to file
# Data for 2837712923 has been successfully exported to file
# Data for 739774489 has been successfully exported to file
# Data for 137367585 has been successfully exported to file
# Data for 141299741 has been successfully exported to file
# Data for 1589907487 has been successfully exported to file
# Data for 258478116 has been successfully exported to file
# Data for 55840808 has been successfully exported to file
# Data for 877428455352217600 has been successfully exported to file
# Data for 294916156 has been successfully exported to file
# Data for 772475576779214848 has been successfully exported to file
# Data for 772155842233831424 has been successfully exported to file
# Data for 256643151 has been successfully exported to file
# Data for 766226088515276800 has been successfully exported to file
# Data for 4469821522 has been successfully exported to file
# Data for 805556194698006528 has been successfully exported to file
# Data for 347607131 has been successfully exported to file
# Data for 2929725533 has been successfully exported to file
# Data for 36704352 has been successfully exported to file
# Data for 20189287 has been successfully exported to file
# Data for 1059852410 has been successfully exported to file
# Data for 206049405 has been successfully exported to file
# Data for 1006785817514250240 has been successfully exported to file
# Data for 116134032 has been successfully exported to file
# Data for 790680 has been successfully exported to file
# Data for 423891097 has been successfully exported to file
# Data for 513112719 has been successfully exported to file
# Data for 2258112673 has been successfully exported to file
# Data for 353636529 has been successfully exported to file
# Data for 406065351 has been successfully exported to file
# Data for 80744646 has been successfully exported to file
# Data for 46318078 has been successfully exported to file
# Data for 1360531694 has been successfully exported to file
# Data for 56627441 has been successfully exported to file
# Data for 634130682 has been successfully exported to file
# User 193728764 not found or has no ID.
# Data for 2295337212 has been successfully exported to file
# Data for 920391689147244544 has been successfully exported to file
# Data for 3287027977 has been successfully exported to file
# Data for 240128281 has been successfully exported to file
# Data for 39325978 has been successfully exported to file
# Data for 113512735 has been successfully exported to file
# Data for 1202983213 has been successfully exported to file
# Data for 876868437498363904 has been successfully exported to file
# Data for 268439864 has been successfully exported to file
# Data for 1118951206448181248 has been successfully exported to file
# Data for 2336493886 has been successfully exported to file
# Data for 318924291 has been successfully exported to file
# Data for 16257347 has been successfully exported to file
# Data for 423104853 has been successfully exported to file
# Data for 25956690 has been successfully exported to file
# Data for 378278231 has been successfully exported to file
# Data for 874379332579405826 has been successfully exported to file
# Data for 46928242 has been successfully exported to file
# Data for 16519549 has been successfully exported to file
# Data for 466882955 has been successfully exported to file
# Data for 3014398348 has been successfully exported to file
# Data for 41161102 has been successfully exported to file
# Data for 707903036941684736 has been successfully exported to file
# Data for 360714671 has been successfully exported to file
# Data for 1069375476622344192 has been successfully exported to file
# Data for 790984 has been successfully exported to file
# Data for 232526281 has been successfully exported to file
# Data for 2305036753 has been successfully exported to file
# Data for 3299611091 has been successfully exported to file
# Data for 1586237918 has been successfully exported to file
# Data for 807670261 has been successfully exported to file
# Data for 382996982 has been successfully exported to file
# Data for 2675708408 has been successfully exported to file
# Data for 1223430648 has been successfully exported to file
# Data for 22024720 has been successfully exported to file
# User 786960912 not found or has no ID.
# Data for 2267288083 has been successfully exported to file
# Data for 84152857 has been successfully exported to file
# Data for 163582516 has been successfully exported to file
# User 286790217 not found or has no ID.
# Data for 20451915 has been successfully exported to file
# Data for 722794248618188800 has been successfully exported to file
# Data for 327422553 has been successfully exported to file
# Data for 545520971 has been successfully exported to file
# Data for 206049898 has been successfully exported to file
# Data for 327684727 has been successfully exported to file
# Data for 635966074 has been successfully exported to file
# Data for 88576304 has been successfully exported to file
# Data for 388502138 has been successfully exported to file
# Data for 85725829 has been successfully exported to file
# Data for 39588492 has been successfully exported to file
# Data for 114299539 has been successfully exported to file
# Data for 78385842 has been successfully exported to file
# Data for 3246396084 has been successfully exported to file
# Data for 111678148 has been successfully exported to file
# Data for 137630414 has been successfully exported to file
# Data for 299373263 has been successfully exported to file
# Data for 3014136535 has been successfully exported to file
# Data for 81007322 has been successfully exported to file
# Data for 2171867880 has been successfully exported to file
# User 531632887 not found or has no ID.
# Data for 532157179 has been successfully exported to file
# User 3020165893 not found or has no ID.
# Data for 32248589 has been successfully exported to file
# Data for 352064277 has been successfully exported to file
# User 10228502 not found or has no ID.
# User 718050444191404032 not found or has no ID.
# Data for 885003066 has been successfully exported to file
# Data for 227545922 has been successfully exported to file
# Data for 1162875732 has been successfully exported to file
# Data for 31462230 has been successfully exported to file
# Data for 1871975262 has been successfully exported to file
# Data for 141300574 has been successfully exported to file
# Data for 20714349 has been successfully exported to file
# Data for 193205108 has been successfully exported to file
# Data for 448009084 has been successfully exported to file
# Data for 762698866407858176 has been successfully exported to file
# Data for 127931276 has been successfully exported to file
# User 3233551254 not found or has no ID.
# Data for 791449 has been successfully exported to file
# Data for 1970279328 has been successfully exported to file
# User 1862538146 not found or has no ID.
# Data for 421532582 has been successfully exported to file
# Data for 878449580 has been successfully exported to file
# Data for 22549433 has been successfully exported to file
# Data for 27530178 has been successfully exported to file
# Data for 469504967 has been successfully exported to file
# Data for 269489101 has been successfully exported to file
# Data for 27530219 has been successfully exported to file
# Data for 3259503600 has been successfully exported to file
# Data for 4905513086 has been successfully exported to file
# Data for 2310280190 has been successfully exported to file
# Data for 1219499012 has been successfully exported to file
# Data for 99881991 has been successfully exported to file
# Data for 38802447 has been successfully exported to file
# Data for 608703511 has been successfully exported to file
# User 1028142835059417088 not found or has no ID.
# Data for 23335967 has been successfully exported to file
# Data for 824737191393779712 has been successfully exported to file
# Data for 605819946 has been successfully exported to file
# Data for 358880317 has been successfully exported to file
# Data for 4112258113 has been successfully exported to file
# Data for 437523529 has been successfully exported to file
# Data for 406590542 has been successfully exported to file
# Data for 339219535 has been successfully exported to file
# Data for 895400182111719424 has been successfully exported to file
# Data for 618665044 has been successfully exported to file
# Data for 70784114 has been successfully exported to file
# Data for 236197005 has been successfully exported to file
# Data for 28054681 has been successfully exported to file
# Data for 42472602 has been successfully exported to file
# Data for 3349157019 has been successfully exported to file
# Data for 1042814112 has been successfully exported to file
# Data for 243799204 has been successfully exported to file
# Data for 393483438 has been successfully exported to file
# Data for 4733801655 has been successfully exported to file
# Data for 4761064634 has been successfully exported to file
# User 537662656 not found or has no ID.
# Data for 1476400334 has been successfully exported to file
# Data for 37229778 has been successfully exported to file
# Data for 831720146091716608 has been successfully exported to file
# Data for 1293948120 has been successfully exported to file
# Data for 247469280 has been successfully exported to file
# Data for 480777445 has been successfully exported to file
# Data for 393483500 has been successfully exported to file
# Data for 1599608046 has been successfully exported to file
# Data for 563090687 has been successfully exported to file
# Data for 416814339 has been successfully exported to file
# Data for 62919941 has been successfully exported to file
# Data for 714996796582264832 has been successfully exported to file
# User 629413127 not found or has no ID.
# Data for 472388869 has been successfully exported to file
# Data for 190846228 has been successfully exported to file
# Data for 851711263 has been successfully exported to file
# Data for 901276986152058881 has been successfully exported to file
# Data for 62657834 has been successfully exported to file
# Data for 273159476 has been successfully exported to file
# Data for 22549812 has been successfully exported to file
# Data for 71308607 has been successfully exported to file
# Data for 81794383 has been successfully exported to file
# Data for 23598426 has been successfully exported to file
# Data for 28054874 has been successfully exported to file
# Data for 21763420 has been successfully exported to file
# Data for 3247445346 has been successfully exported to file
# Data for 224925029 has been successfully exported to file
# Data for 366744934 has been successfully exported to file
# Data for 57152873 has been successfully exported to file
# Data for 1337464171 has been successfully exported to file
# Data for 76289403 has been successfully exported to file
# Data for 708394182595883008 has been successfully exported to file
# ...
# Data for 46306646 has been successfully exported to file
# Data for 2315949402 has been successfully exported to file
# Data for 4150170979 has been successfully exported to file
# Data for 28743012 has been successfully exported to file
# Data for 266507619 has been successfully exported to file
# Data for 706123118 has been successfully exported to file
# Data for 1128437108 has been successfully exported to file
# Data for 71210357 has been successfully exported to file
# Data for 452367737 has been successfully exported to file
# Data for 925537664 has been successfully exported to file
# Data for 2385417602 has been successfully exported to file
# Data for 2715194757 has been successfully exported to file
# User 752656477387620352 not found or has no ID.
# Data for 923599748912775168 has been successfully exported to file
# Data for 305567120 has been successfully exported to file
# Data for 23762312 has been successfully exported to file
# Data for 564303265 has been successfully exported to file
# Data for 39736270 has been successfully exported to file
# Data for 350114766 has been successfully exported to file
# Data for 324703658 has been successfully exported to file
# Data for 21927348 has been successfully exported to file
# Data for 138843574 has been successfully exported to file
# Data for 969573265143365634 has been successfully exported to file
# Data for 263099844 has been successfully exported to file
# User 1229624773 not found or has no ID.
# Data for 892794832569028608 has been successfully exported to file
# User 878497715319185408 not found or has no ID.
# Data for 2839975385 has been successfully exported to file
# Data for 2973406683 has been successfully exported to file
# Data for 732075487 has been successfully exported to file
# User 393123305 not found or has no ID.
# Data for 1404999145 has been successfully exported to file
# Data for 772126485679308804 has been successfully exported to file
# Data for 1095187623482544130 has been successfully exported to file
# Data for 35034615 has been successfully exported to file
# Data for 315528702 has been successfully exported to file
# Data for 195991042 has been successfully exported to file
# Data for 4925593090 has been successfully exported to file
# Data for 87725574 has been successfully exported to file
# Data for 14849562 has been successfully exported to file
# Data for 21665313 has been successfully exported to file
# Data for 15373859 has been successfully exported to file
# Data for 419862060 has been successfully exported to file
# Data for 467047990 has been successfully exported to file
# User 32937527 not found or has no ID.
# User 1948423759 not found or has no ID.
# Data for 235312723 has been successfully exported to file
# Data for 193631827 has been successfully exported to file
# Data for 772231861439459328 has been successfully exported to file
# Data for 169776732 has been successfully exported to file
# Data for 98473573 has been successfully exported to file
# Data for 209884774 has been successfully exported to file
# Data for 164271720 has been successfully exported to file
# Data for 2616104577 has been successfully exported to file
# Data for 605460099 has been successfully exported to file
# Data for 842897385055428609 has been successfully exported to file
# User 69375632 not found or has no ID.
# User 126523026 not found or has no ID.
# Data for 47355553 has been successfully exported to file
# Data for 494573219 has been successfully exported to file
# Data for 17471149 has been successfully exported to file
# Data for 22451908 has been successfully exported to file
# Data for 164009670 has been successfully exported to file
# Data for 17733320 has been successfully exported to file
# Data for 210933449 has been successfully exported to file
# Data for 2793051859 has been successfully exported to file
# Data for 287217365 has been successfully exported to file
# Data for 436639453 has been successfully exported to file
# Data for 1684444903 has been successfully exported to file
# Data for 386307826 has been successfully exported to file
# Data for 912719028761894912 has been successfully exported to file
# Data for 3188365045 has been successfully exported to file
# Data for 240555787 has been successfully exported to file
# Data for 95852295 has been successfully exported to file
# Data for 298751766 has been successfully exported to file
# Data for 95590168 has been successfully exported to file
# Data for 2860160796 has been successfully exported to file
# Data for 1249548061 has been successfully exported to file
# Data for 830203172840960000 has been successfully exported to file
# Data for 39753512 has been successfully exported to file
# Data for 789278563002380288 has been successfully exported to file
# Data for 1517197098 has been successfully exported to file
# Data for 36869938 has been successfully exported to file
# Data for 331257657 has been successfully exported to file
# Data for 438212411 has been successfully exported to file
# Data for 73045822 has been successfully exported to file
# Data for 855283519 has been successfully exported to file
# Data for 2416088899 has been successfully exported to file
# Data for 24024918 has been successfully exported to file
# Data for 816504743606435840 has been successfully exported to file
# Data for 352491356 has been successfully exported to file
# Data for 320771933 has been successfully exported to file
# Data for 834617479716622336 has been successfully exported to file
# Data for 865245050 has been successfully exported to file
# Data for 21665671 has been successfully exported to file
# Data for 913792196779708416 has been successfully exported to file
# Data for 66754444 has been successfully exported to file
# Data for 733910928 has been successfully exported to file
# Data for 334927761 has been successfully exported to file
# Data for 54433689 has been successfully exported to file
# Data for 316053407 has been successfully exported to file
# Data for 7772072 has been successfully exported to file
# Data for 914266027 has been successfully exported to file
# Data for 1850120119 has been successfully exported to file
# Data for 149329864 has been successfully exported to file
# Data for 1576179685 has been successfully exported to file
# Data for 1001035760 has been successfully exported to file
# Data for 378968051 has been successfully exported to file
# Data for 300587013 has been successfully exported to file
# Data for 834707676252737536 has been successfully exported to file
# Data for 792994159305035776 has been successfully exported to file
# Data for 3305805847 has been successfully exported to file
# Data for 2241763351 has been successfully exported to file
# Data for 164010013 has been successfully exported to file
# Data for 3069351970 has been successfully exported to file
# Data for 102406191 has been successfully exported to file
# Data for 3180501039 has been successfully exported to file
# Data for 2160498763 has been successfully exported to file
# Data for 442144847 has been successfully exported to file
# Data for 26384462 has been successfully exported to file
# Data for 28481618 has been successfully exported to file
# Data for 57841792 has been successfully exported to file
# Data for 203856001 has been successfully exported to file
# Data for 4769618060 has been successfully exported to file
# Data for 91134100 has been successfully exported to file
# Data for 4626581 has been successfully exported to file
# Data for 177903766 has been successfully exported to file
# Data for 635869338 has been successfully exported to file
# User 177641630 not found or has no ID.
# Data for 1198954656 has been successfully exported to file
# Data for 2908133537 has been successfully exported to file
# User 940799592324575232 not found or has no ID.
# Data for 3732576437 has been successfully exported to file
# Data for 66492624 has been successfully exported to file
# Data for 25073877 has been successfully exported to file
# Data for 23501022 has been successfully exported to file
# User 259954913 not found or has no ID.
# Data for 439785709 has been successfully exported to file
# Data for 467048692 has been successfully exported to file
# Data for 1041105041896091648 has been successfully exported to file
# Data for 259168509 has been successfully exported to file
# Data for 1006016766 has been successfully exported to file
# Data for 3353516302 has been successfully exported to file
# Data for 970889486 has been successfully exported to file
# User 1646172445 not found or has no ID.
# Data for 25073959 has been successfully exported to file
# Data for 1591122223 has been successfully exported to file
# Data for 31365425 has been successfully exported to file
# Data for 24287541 has been successfully exported to file
# Data for 2760808768 has been successfully exported to file
# Data for 466524483 has been successfully exported to file
# Data for 2952698183 has been successfully exported to file
# Data for 11442512 has been successfully exported to file
# Data for 2492897617 has been successfully exported to file
# Data for 147233107 has been successfully exported to file
# Data for 3187579221 has been successfully exported to file
# Data for 348559702 has been successfully exported to file
# Data for 9083222 has been successfully exported to file
# Data for 56617880 has been successfully exported to file
# Data for 1490721140 has been successfully exported to file
# Data for 17996152 has been successfully exported to file
# Data for 386570617 has been successfully exported to file
# Data for 229808502 has been successfully exported to file
# Data for 825135151386537985 has been successfully exported to file
# Data for 26554371 has been successfully exported to file
# Data for 856942682484207616 has been successfully exported to file
# Data for 84842910 has been successfully exported to file
# Data for 2440731044 has been successfully exported to file
# User 235837865 not found or has no ID.
# Data for 772386030917943296 has been successfully exported to file
# Data for 842241073921556480 has been successfully exported to file
# Data for 346986940 has been successfully exported to file
# Data for 24025545 has been successfully exported to file
# Data for 528652747 has been successfully exported to file
# Data for 550410719 has been successfully exported to file
# Data for 2502597096 has been successfully exported to file
# Data for 17471979 has been successfully exported to file
# Data for 140417519 has been successfully exported to file
# Data for 19569136 has been successfully exported to file
# Data for 388405753 has been successfully exported to file
# Data for 241605117 has been successfully exported to file
# Data for 862624266 has been successfully exported to file
# Data for 151951887 has been successfully exported to file
# Data for 23501330 has been successfully exported to file
# Data for 214080021 has been successfully exported to file
# Data for 368220699 has been successfully exported to file
# Data for 30317085 has been successfully exported to file
# Data for 228497955 has been successfully exported to file
# Data for 772313969402847233 has been successfully exported to file
# Data for 161126952 has been successfully exported to file
# Data for 33724970 has been successfully exported to file
# Data for 17996334 has been successfully exported to file
# Data for 284072502 has been successfully exported to file
# Data for 602315322 has been successfully exported to file
# Data for 105028161 has been successfully exported to file
# Data for 1710398022 has been successfully exported to file
# User 2802227786 not found or has no ID.
# Data for 771921239841570816 has been successfully exported to file
# Data for 40540760 has been successfully exported to file
# Data for 960333542197776384 has been successfully exported to file
# Data for 1012070142719774720 has been successfully exported to file
# Data for 888841192431112192 has been successfully exported to file
# Data for 65182307 has been successfully exported to file
# Data for 3113654888 has been successfully exported to file
# Data for 96115307 has been successfully exported to file
# Data for 22190703 has been successfully exported to file
# Data for 24550000 has been successfully exported to file
# Data for 842869843649007617 has been successfully exported to file
# Data for 240818816 has been successfully exported to file
# Data for 235696484 has been successfully exported to file
# Data for 773495426 has been successfully exported to file
# Data for 2319882889 has been successfully exported to file
# Data for 21928586 has been successfully exported to file
# Data for 749242830728601600 has been successfully exported to file
# Data for 797734470178709504 has been successfully exported to file
# Data for 139631247 has been successfully exported to file
# Data for 772159573360779264 has been successfully exported to file
# Data for 772406577198407680 has been successfully exported to file
# Data for 14326420 has been successfully exported to file
# Data for 2417662617 has been successfully exported to file
# Data for 873561533116280832 has been successfully exported to file
# Data for 117611176 has been successfully exported to file
# User 35035820 not found or has no ID.
# Data for 257071795 has been successfully exported to file
# Data for 370842296 has been successfully exported to file
# Data for 1850645180 has been successfully exported to file
# Data for 510853259 has been successfully exported to file
# Data for 315005641 has been successfully exported to file
# Data for 8559342 has been successfully exported to file
# Data for 221158127 has been successfully exported to file
# Data for 3857907862 has been successfully exported to file
# Data for 475175670 has been successfully exported to file
# Data for 51813111 has been successfully exported to file
# User 628267790 not found or has no ID.
# Data for 44473103 has been successfully exported to file
# Data for 154573594 has been successfully exported to file
# Data for 401775393 has been successfully exported to file
# Data for 242916135 has been successfully exported to file
# Data for 15248067 has been successfully exported to file
# Data for 14850863 has been successfully exported to file
# Data for 399153972 has been successfully exported to file
# Data for 7510842 has been successfully exported to file
# Data for 117349182 has been successfully exported to file
# Data for 15637319 has been successfully exported to file
# Data for 435355815 has been successfully exported to file
# Data for 197303127 has been successfully exported to file
# Data for 301112153 has been successfully exported to file
# Data for 241343330 has been successfully exported to file
# Data for 778738531 has been successfully exported to file
# Data for 865988447852412928 has been successfully exported to file
# Data for 289053567 has been successfully exported to file
# Data for 147495812 has been successfully exported to file
# Data for 616995720 has been successfully exported to file
# Data for 18783114 has been successfully exported to file
# Data for 862624650 has been successfully exported to file
# User 3951991698 not found or has no ID.
# Data for 17734567 has been successfully exported to file
# Data for 334666664 has been successfully exported to file
# Data for 758538844878704640 has been successfully exported to file
# Data for 185506731 has been successfully exported to file
# User 3024001965 not found or has no ID.
# Data for 22191023 has been successfully exported to file
# Data for 451582909 has been successfully exported to file
# Data for 703241169 has been successfully exported to file
# Data for 276208595 has been successfully exported to file
# Data for 3840981 has been successfully exported to file
# Data for 19307503 has been successfully exported to file
# Data for 4633304052 has been successfully exported to file
# Data for 212302245 has been successfully exported to file
# Data for 1390320662 has been successfully exported to file
# Data for 43949085 has been successfully exported to file
# Data for 112368673 has been successfully exported to file

# %%
# FIX FILE
import json

with open('profile_and_tweets_followers.json', 'r',encoding='utf-8') as file:
    data = file.read()

# Replace '}{' with '},{'
corrected_data = data.replace('}{', '},{')

with open('fixed_profile_and_tweets_followers.json', 'w',encoding='utf-8') as file:
    file.write(corrected_data)

# %%
import csv
import json

# Đọc tệp CSV và tạo một từ điển
account_types = {}
with open('twitter_human_bots_dataset.csv', mode='r', encoding='utf-8') as csv_file:
    csv_reader = csv.DictReader(csv_file)
    for row in csv_reader:
        account_types[int(row['id'])] = row['account_type']

# Đọc tệp JSON
with open('fixed_profileBotorNot.json', 'r', encoding='utf-8') as json_file:
    users_data = json.load(json_file)

# Cập nhật thông tin account_type cho mỗi người dùng
for user in users_data:
    user_id = user['id']
    if user_id in account_types:
        user['account_type'] = account_types[user_id]

# Ghi dữ liệu đã được cập nhật vào một tệp JSON mới
with open('updated_fixed_profileBotorNot.json', 'w', encoding='utf-8') as file:
    json.dump(users_data, file, indent=4)
